# %% [markdown]
# # Top 10 Languages Trends
# # Question N°3
# What are the trends in top 10 languages popularity over last 11 years?
# Now we can look at the trends, plotting data about top 5 languages.

# %% [markdown]
# We can observe that these 10 languages are the most used languages over the 10 years of surveys:
# 1. JavaScript
# 2. PHP
# 3. C#
# 4. Java
# 5. C++
# 6. C
# 7. Python
# 8. TypeScript
# 9. Objective-C
# 10. Ruby

# %%
popular_languages = ["JavaScript", "PHP", "C#", "Java", "C++", "C", "Python", "TypeScript", "Objective-C", "Ruby"]

# %% [markdown]
# ## 5. Results Analysis
# For the purposes of this quesion,  previous CRISP-DM stages (Business Understanding, Data Understanding,
# Data Preparation and Data Modeling) can be reused, hence,
# I'll proceed with the results' analysis stage, delving deeper into the analysis of results.

# %% [markdown]
# First question: "What languages were the most popular in each year?"

# %% [markdown]
# ### Plotting the trends in top 10 languages throughout years
# Now I will plot the trend of languages popularity throughout years.

# %% [markdown]
# Before plotting data, I need to make data ready to be plotted, so I will prepare a Dataframe </br>
# containing only top 10 languages' by popularity, throughout reference years.

# %% [markdown]
# First, I need to import the data from the previous notebook

# %%
# %store -r s_2011_proficiencies_stats
# %store -r s_2011_proficiencies_percentages
# %store -r s_2012_proficiencies_stats
# %store -r s_2012_proficiencies_percentages
# %store -r s_2013_proficiencies_stats
# %store -r s_2013_proficiencies_percentages
# %store -r s_2014_proficiencies_stats
# %store -r s_2014_proficiencies_percentages
# %store -r s_2015_proficiencies_stats
# %store -r s_2015_proficiencies_percentages
# %store -r s_2016_proficiencies_stats
# %store -r s_2016_proficiencies_percentages
# %store -r s_2017_proficiencies_stats
# %store -r s_2017_proficiencies_percentages
# %store -r s_2018_proficiencies_stats
# %store -r s_2018_proficiencies_percentages
# %store -r s_2019_proficiencies_stats
# %store -r s_2019_proficiencies_percentages
# %store -r s_2020_proficiencies_stats
# %store -r s_2020_proficiencies_percentages
# %store -r s_2021_proficiencies_stats
# %store -r s_2021_proficiencies_percentages
# %store -r s_2022_proficiencies_stats
# %store -r s_2022_proficiencies_percentages

# %%
import sys
import os

# Get the parent directory
parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# Append the parent directory to the system path
sys.path.append(parent_dir)

# %%
import pandas as pd
from preparation.data_load import get_10most_popular_languages_by_year

# %%
s_surveys_data = {"2011": [s_2011_proficiencies_stats, s_2011_proficiencies_percentages], "2012": [s_2012_proficiencies_stats, s_2012_proficiencies_percentages],
                  "2013": [s_2013_proficiencies_stats, s_2013_proficiencies_percentages], "2014": [s_2014_proficiencies_stats, s_2014_proficiencies_percentages],
                  "2015": [s_2015_proficiencies_stats, s_2015_proficiencies_percentages], "2016": [s_2016_proficiencies_stats, s_2016_proficiencies_percentages],
                  "2017": [s_2017_proficiencies_stats, s_2017_proficiencies_percentages], "2018": [s_2018_proficiencies_stats, s_2018_proficiencies_percentages],
                  "2019": [s_2019_proficiencies_stats, s_2019_proficiencies_percentages], "2020": [s_2020_proficiencies_stats, s_2020_proficiencies_percentages],
                  "2021": [s_2021_proficiencies_stats, s_2021_proficiencies_percentages], "2022": [s_2022_proficiencies_stats, s_2022_proficiencies_percentages]}

languages_popularity_df = pd.DataFrame(columns=popular_languages, index=s_surveys_data.keys())


get_10most_popular_languages_by_year(languages_popularity_df, s_surveys_data, popular_languages)

# %%
languages_popularity_df
# Out:
#      JavaScript    PHP     C#   Java    C++      C Python TypeScript  \
# 2011       1419    788   1352    861    740    741    575          0
# 2012       3127   1925   2468   2348   1526   1484   1210          0
# 2013       5149   2324   3027   3020   1696   1436   1880          0
# 2014       3836   1710   2378   2479   1418   1174   1473          0
# 2015      12433   6529   6949   8219   4529   3612   5238          0
# 2016      28904  12780  15283  17942   9589   7678  12282          0
# 2017      22875  10290  12476  14524   8155   6974  11704       3488
# 2018      54686  24071  26954  35521  19872  18042  30359      13626
# 2019      59219  23030  27097  35917  20524  18017  36443      18523
# 2020      38822  15007  18041  23074  13707  12487  25287      14578
# 2021      55300  18130  22984  29162  20057  17329  39792      24909
# 2022      46443  14827  19883  23644  16024  13692  34155      24752
#
#      Objective-C  Ruby  JavaScript percentage  PHP percentage  C# percentage  \
# 2011           0   285              50.444365       28.012798      48.062567
# 2012         605   577              50.088099       30.834535      39.532276
# 2013         955   794              52.853623       23.855471      31.071649
# 2014         675   593              50.189716       22.373414      31.113437
# 2015        1719  1765              47.661581       25.028751      26.638810
# 2016        3202  4383              51.586650       22.809209      27.276459
# 2017        2349  3324              44.510819       20.022572      24.276152
# 2018        5510  7911              55.319407       24.349805      27.266198
# 2019        4191  7331              66.625789       25.910467      30.486145
# 2020        2340  4046              60.225563       23.280743      27.987465
# 2021        2310  5569              66.275962       21.728448      27.545872
# 2022        1698  4299              63.387836       20.236665      27.137359
#
#       Java percentage  C++ percentage  C percentage  Python percentage  \
# 2011        30.607892       26.306434     26.341984          20.440811
# 2012        37.610123       24.443377     23.770623          19.381708
# 2013        30.999795       17.409156     14.740300          19.297885
# 2014        32.434908       18.552924     15.360461          19.272537
# 2015        31.507322       17.361803     13.846508          20.079736
# 2016        32.022131       17.114046     13.703373          21.920400
# 2017        28.261208       15.868229     13.570205          22.773973
# 2018        35.932426       20.102170     18.250974          30.710637
# 2019        40.409302       23.091030     20.270468          41.001091
# 2020        35.795287       21.264020     19.371403          39.228371
# 2021        34.950083       24.037920     20.768466          47.689929
# 2022        32.270568       21.870394     18.687558          46.616531
#
#       TypeScript percentage  Objective-C percentage  Ruby percentage
# 2011               0.000000                0.000000        10.131532
# 2012               0.000000                9.690854         9.242351
# 2013               0.000000                9.802915         8.150277
# 2014               0.000000                8.831611         7.758733
# 2015               0.000000                6.589742         6.766081
# 2016               0.000000                5.714796         7.822595
# 2017               6.787049                4.570750         6.467933
# 2018              13.783825                5.573820         8.002630
# 2019              20.839756                4.715187         8.247921
# 2020              22.615225                3.630102         6.276663
# 2021              29.852946                2.768490         6.674337
# 2022              33.782825                2.317519         5.867500

# %% [markdown]
# Now I can plot data, but before that, for readability purposes, I'll set default matplotlib size.

# %%
import matplotlib.pyplot as plt

print("Before, figure default size is: ", plt.rcParams["figure.figsize"])
plt.rcParams["figure.figsize"] = (20, 10)
print("After, figure default size is: ", plt.rcParams["figure.figsize"])
# Out:
# Before, figure default size is:  [6.4, 4.8]
# After, figure default size is:  [20.0, 10.0]

# %%
absolute_values_columns = popular_languages

languages_popularity_df[absolute_values_columns].plot.line()
# Out:
# <Axes: >

# %%
percentages_values_columns = [pl+' percentage' for pl in absolute_values_columns]

languages_popularity_df[percentages_values_columns].plot.line()
# Out:
# <Axes: >
