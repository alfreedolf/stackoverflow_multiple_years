# %% [markdown]
# # Stack Overflow Developer Survey Data (2011-2021) Analysis
#
# This notebook presents project methodology and purposes.
# It loads data from files into Pandas Dataframes, ready to be analyzed.
# Here will follow the general description of the methodology used in the project.

# %% [markdown]
# ## CRISP-DM analysis
# In the following paragraphs I will approach the dataset using the CRISP-DM methodology:
# CRISP-DM stands for Cross-Industry Standard Process for Data Mining and is a process structured in 5 steps:
# 1. Business Understanding (common)
# 2. Data Understanding (common)
# 3. Data Preparation (specific to the question)
# 4. Data Modeling (specific to the question)
# 5. Results Analysis (specific to the question)
# 6. Deployment (not implemented in this project)

# %% [markdown]
# ## 1. Business Understanding
#
# In this section, I will formulate three questions about the Stack Overflow survey dataset.
#
# For this purpose, I will use data from the following list of years:
# 1. 2011
# 2. 2012
# 3. 2013
# 4. 2014
# 5. 2015
# 6. 2016
# 7. 2017
# 8. 2018
# 9. 2019
# 10. 2020
# 11. 2021
#
# The questions will be the following:<br/>
# 1. What languages were the most popular in each year?
# 2. What are the trends in top 10 languages popularity through last 11 years?
# 3. Does the country of origin influence the preferred/most used language?
# 4. Does the amount of years in programming influence the preferred/most used language?
# 5. Does the languages currently known by a developer influence the desire to learn a specific language in the future?

# %% [markdown]
# ## 2. Data Understanding
#
# In this section, I will take a look at the data and check about the above formulated questions,
# exploring dataframes features

# %% [markdown]
# ### Data Gathering and Access
#
# The data has to be loaded from CSV files, first.
#
# So I will use a support function to do this in the form of a dictionary, whose keys will be the year of reference

# %% [markdown]
# Before proceeding, I need to import pandas libraries:

# %%
import pandas as pd

# %% [markdown]
# Now I'll load data from CSV files:

# %%
# reading survey data from oldest to newest
from preparation.data_load import load_surveys_data_from_csv
df_surveys_11_to_21 = load_surveys_data_from_csv()
# Out:
# /media/alfonso/Text/workspace/stackoverflow_multiple_years/preparation/data_load.py:38: DtypeWarning: Columns (46,48,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   surveys_years_df[y] = load_from_csv(os.path.join(base_dir, data_path,
# /media/alfonso/Text/workspace/stackoverflow_multiple_years/preparation/data_load.py:38: DtypeWarning: Columns (5,108,121,196,197,198) have mixed types.Specify dtype option on import or set low_memory=False.
#   surveys_years_df[y] = load_from_csv(os.path.join(base_dir, data_path,
# /media/alfonso/Text/workspace/stackoverflow_multiple_years/preparation/data_load.py:38: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types.Specify dtype option on import or set low_memory=False.
# ...

# %% [markdown]
# ### Data Exploration
# In this section I'll have a look at each dataframe comprising data from each year.

# %% [markdown]
# #### Preliminary operations
#
# Before proceeding with data exploration, I need to get dimensionality parameters from resulting pandas Dataframe, in order to
# guarantee correct display of Dataframe during data exploration phases.
#
# First I will compute these parameters on dataframe:

# %%
from preparation.data_load import get_dataset_max_shapes
max_rows, max_cols = get_dataset_max_shapes(df_surveys_11_to_21)

# %% [markdown]
# Then I will set these parameters on the Notebook:

# %%
# setting the option from dataset computed parameters
pd.set_option('display.max_columns', max_rows)
pd.set_option('display.max_columns', max_cols)

# %% [markdown]
# Now I'll go through dataset by year, dataframe by dataframe, looking at features of each of them.

# %%
# 2011 survey data dataframe
df_surveys_11_to_21[2011].head(3)
# Out:
#   What Country or Region do you live in?  \
# 0                               Response
# 1                                 Africa
# 2                           Other Europe
#
#   Which US State or Territory do you live in? How old are you?  \
# 0                                    Response         Response
# 1                                         NaN             < 20
# 2                                         NaN            25-29
#
#   How many years of IT/Programming experience do you have?  \
# 0                                           Response
# 1                                                 <2
# 2                                              41310
#
#   How would you best describe the industry you work in?  \
# 0                                           Response
# 1                                         Consulting
# 2                                  Software Products
#
#   Which best describes the size of your company?  \
# ...

# %%
# 2012 survey data dataframe
df_surveys_11_to_21[2012].head(3)
# Out:
#   What Country or Region do you live in?  \
# 0                               Response
# 1                                  India
# 2                                Germany
#
#   Which US State or Territory do you live in? How old are you?  \
# 0                                    Response         Response
# 1                                         NaN            20-24
# 2                                         NaN            25-29
#
#   How many years of IT/Programming experience do you have?  \
# 0                                           Response
# 1                                                 <2
# 2                                                 <2
#
#   How would you best describe the industry you currently work in?  \
# 0                                           Response
# 1                                         Consulting
# 2                                              Other
#
#   Which best describes the size of your company?  \
# ...

# %%
# 2013 survey data dataframe
df_surveys_11_to_21[2013].head(3)
# Out:
#   What Country or Region do you live in?  \
# 0                               Response
# 1                         United Kingdom
# 2               United States of America
#
#   Which US State or Territory do you live in? How old are you?  \
# 0                                    Response         Response
# 1                                         NaN            35-39
# 2                                      Oregon            25-29
#
#   How many years of IT/Programming experience do you have?  \
# 0                                           Response
# 1                                          6/10/2013
# 2                                          6/10/2013
#
#   How would you best describe the industry you currently work in?  \
# 0                                           Response
# 1                                  Finance / Banking
# 2                                             Retail
#
#   How many people work for your company?  \
# 0                               Response
# ...

# %%
# 2014 survey data dataframe
df_surveys_11_to_21[2014].head(3)
# Out:
#   What Country do you live in?              Unnamed: 1  \
# 0                     Response  Other (please specify)
# 1                        India                     NaN
# 2                     Thailand                     NaN
#
#   Which US State or Territory do you live in? How old are you?  \
# 0                                    Response         Response
# 1                                         NaN            30-34
# 2                                         NaN            20-24
#
#   What is your gender?  \
# 0             Response
# 1               Female
# 2                 Male
#
#   How many years of IT/Programming experience do you have?  \
# 0                                           Response
# 1                                          6/10/2014
# 2                                                 <2
#
#   Which of the following best describes your occupation?  \
# 0                                           Response
# ...

# %%
# 2015 survey data dataframe
df_surveys_11_to_21[2015].head(3)
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2      Unnamed: 3  \
# 0    Country        Age     Gender  Tabs or Spaces
# 1    Croatia      25-29       Male            Tabs
# 2     France      20-24       Male          Spaces
#
#                           Unnamed: 4              Unnamed: 5  \
# 0  Years IT / Programming Experience              Occupation
# 1                        2 - 5 years  Back-end web developer
# 2                        1 - 2 years  Back-end web developer
#
#                  Unnamed: 6                          Unnamed: 7  \
# 0  Desktop Operating System  Desktop Operating System: write-in
# 1                    Ubuntu                                 NaN
# 2                 Windows 7                                 NaN
#
#           Select all that apply                    Unnamed: 9  \
# 0  Current Lang & Tech: Android  Current Lang & Tech: Arduino
# 1                           NaN                           NaN
# ...

# %%
# 2016 survey data dataframe
df_surveys_11_to_21[2016].head(3)
# Out:
#    Unnamed: 0 collector      country   un_subregion     so_region age_range  \
# 0        1888  Facebook  Afghanistan  Southern Asia  Central Asia     20-24
# 1        4637  Facebook  Afghanistan  Southern Asia  Central Asia     30-34
# 2       11164  Facebook  Afghanistan  Southern Asia  Central Asia       NaN
#
#    age_midpoint gender              self_identification  \
# 0          22.0   Male                       Programmer
# 1          32.0   Male  Developer; Engineer; Programmer
# 2           NaN    NaN                              NaN
#
#                occupation                                occupation_group  \
# 0                     NaN                                             NaN
# 1  Mobile developer - iOS  Mobile Dev (Android, iOS, WP & Multi-Platform)
# 2                     NaN                                             NaN
#
#   experience_range  experience_midpoint       salary_range  salary_midpoint  \
# ...

# %%
# 2017 survey data dataframe
df_surveys_11_to_21[2017].head(3)
# Out:
#    Respondent            Professional ProgramHobby         Country  \
# 0           1                 Student    Yes, both   United States
# 1           2                 Student    Yes, both  United Kingdom
# 2           3  Professional developer    Yes, both  United Kingdom
#
#        University                        EmploymentStatus  \
# 0              No  Not employed, and not looking for work
# 1  Yes, full-time                      Employed part-time
# 2              No                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
#
#                              MajorUndergrad  \
# 0                                       NaN
# 1  Computer science or software engineering
# 2  Computer science or software engineering
#
#                                           HomeRemote  \
# ...

# %%
# 2018 survey data dataframe
df_surveys_11_to_21[2018].head(3)
# Out:
#    Respondent Hobby OpenSource         Country Student          Employment  \
# 0           1   Yes         No           Kenya      No  Employed part-time
# 1           3   Yes        Yes  United Kingdom      No  Employed full-time
# 2           4   Yes        Yes   United States      No  Employed full-time
#
#                               FormalEducation  \
# 0  Bachelorâs degree (BA, BS, B.Eng., etc.)
# 1  Bachelorâs degree (BA, BS, B.Eng., etc.)
# 2                            Associate degree
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
#
#                                              DevType       YearsCoding  \
# ...

# %%
# 2019 survey data dataframe
df_surveys_11_to_21[2019].head(3)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %%
# 2020 survey data dataframe
df_surveys_11_to_21[2020].head(3)
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
# 1           2  I am a developer by profession       No  NaN         19
# 2           3     I code primarily as a hobby      Yes  NaN         15
#
#   CompFreq  CompTotal  ConvertedComp             Country    CurrencyDesc  \
# 0  Monthly        NaN            NaN             Germany   European Euro
# 1      NaN        NaN            NaN      United Kingdom  Pound sterling
# 2      NaN        NaN            NaN  Russian Federation             NaN
#
#   CurrencySymbol DatabaseDesireNextYear  \
# 0            EUR   Microsoft SQL Server
# 1            GBP                    NaN
# 2            NaN                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
#
# ...

# %%
# 2021 survey data dataframe
df_surveys_11_to_21[2021].head(3)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
#
#                                           Employment             Country  \
# 0  Independent contractor, freelancer, or self-em...            Slovakia
# 1                                 Student, full-time         Netherlands
# 2                                 Student, full-time  Russian Federation
#
#   US_State UK_Country                                            EdLevel  \
# 0      NaN        NaN  Secondary school (e.g. American high school, G...
# 1      NaN        NaN     Bachelorâs degree (B.A., B.S., B.Eng., etc.)
# 2      NaN        NaN     Bachelorâs degree (B.A., B.S., B.Eng., etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# ...

# %% [markdown]
# To share the loaded data between notebooks, I will run a special line

# %%
# %store df_surveys_11_to_21
# Out:
# Stored 'df_surveys_11_to_21' (dict)
